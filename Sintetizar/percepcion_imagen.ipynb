# %%
from skimage import io, color

img = io.imread("img/mario.jpg")
io.imshow(img)
print(img) #imprime matriz de colores
# Out:
# [[[ 71 112  76   0]
#   [ 71 112  76   0]
#   [ 71 112  76   0]
#   ...
#   [ 71 112  76   0]
#   [ 71 112  76   0]
#   [ 71 112  76   0]]
#
#  [[ 71 112  76   0]
#   [ 71 112  76   0]
#   [ 71 112  76   0]
#   ...
#   [ 71 112  76   0]
#   [ 71 112  76   0]
#   [ 71 112  76   0]]
#
#  [[ 71 112  76   0]
#   [ 71 112  76   0]
#   [ 71 112  76   0]
#   ...
#   [ 71 112  76   0]
#   [ 71 112  76   0]
#   [ 71 112  76   0]]
#
#  ...
#
#  [[ 71 112  76   0]
#   [ 71 112  76   0]
#   [ 71 112  76   0]
#   ...
#   [ 71 112  76   0]
#   [ 71 112  76   0]
#   [ 71 112  76   0]]
#
#  [[ 71 112  76   0]
#   [ 71 112  76   0]
#   [ 71 112  76   0]
#   ...
#   [ 71 112  76   0]
#   [ 71 112  76   0]
#   [ 71 112  76   0]]
#
#  [[ 71 112  76   0]
#   [ 71 112  76   0]
#   [ 71 112  76   0]
#   ...
#   [ 71 112  76   0]
#   [ 71 112  76   0]
#   [ 71 112  76   0]]]

# %%
#print(img.shape) #escala de colores
imgg = io.imread("img/hongo.jpg")
n = color.rgb2gray(imgg)
io.imshow(n)
io.show()
print(imgg.shape)
# Out:
# (200, 286, 3)

# %%
#Transformacion blanco y negro puro
white_black = color.rgb2gray(imgg)
rows, cols = white_black.shape

for i in range(rows):
	for j in range(cols):
		if(white_black[i,j] <= 0.5):
			white_black[i,j] = 0
		else:
			white_black[i,j] = 1
io.imshow(white_black)
io.show
# Out:
# <function skimage.io._io.show()>

# %%
import skimage
vieja = io.imread("img/vieja.jpg")
#ruido gaussiano
noise = skimage.util.random_noise(vieja, mode="gaussian", var=0.00001)

io.imshow(noise)

# %%
import numpy as np
mean = 0.9999999999999
var = 0.01

noise = np.random.normal(mean, var**0.0000000000005, img.shape)
noisy = img + noise
noisy = np.clip(noisy,0.0,1.0)
io.imshow(noise)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
