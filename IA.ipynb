# %%
print("Hola")
# Out:
# Hola

# %%
def funcion(word):
    a = word
    print("Hola a todos")
funcion(1)
# Out:
# Hola a todos

# %%
import matplotlib.pyplot as plt

# %%
x = [1,2,3,4,5]
y = [1,3,4,5,6]
plt.plot(x,y)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt


data2=[55,20,20,20,0]
data3=[178,60,70,80,100]

year=["2015-2","2016-2","2017-2","2018-2","2019-2"]

plt.figure(figsize=(9,7))
plt.bar(year,data3,color="green",label="normal")
plt.bar(year,data2,color="yellow",bottom=np.array(data3),label="Primera calidad")
#plt.bar(year,data1,color="red",bottom=np.array(data3)+np.array(data2),label="C++")

plt.legend(loc="lower left",bbox_to_anchor=(2.0,2.0))
